# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2019-12-07 16:42:27--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  23.2MB/s    in 4.8s
#
# 2019-12-07 16:42:32 (16.7 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "When my wife and I decided to watch this movie we thought it couldn't fail. I love Billy Crystal, my wife loves Julia Roberts and everyone we talked to said they loved it.<br /><br />We were misled, in spades.<br /><br />On my part, I felt Billy Crystal's character was extremely one-dimensional and did very little for the film. Sure, he cracked a couple of good jokes, but as a character he did nothing but take up space.<br /><br />And poor Julia Roberts. In past shows she plays well as a strong-willed, self-determined lady. In this flick, she seems completely repressed and had very little fire. This is not the Julia Roberts that my wife enjoys watching.<br /><br />OK, if I were to find one good thing, it would have to be Christopher Walken. Now that's entertainment. But, just like Billy Crystal, hardly anything is shown of his character.<br /><br />If you're looking for a night of mindless laughs with very little redeeming value, go see it. But if you're looking for a smart, romantic comedy, this is not your film. It's none of the above."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

# Solution:
# The test data shouldn't contain the ground truth labels as they are what the model is
# trying to predict. We will end up using them afterward to compare the predictions to.

# NOT CORRECT: pd.concat([test_y, test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False) #CORRECT

pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a tuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='0.90-1'. For example:
# 	get_image_uri(region, 'xgboost', '0.90-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = None

# Solution:
xgb = sagemaker.estimator.Estimator(container, # The location of the container we wish to use
                                    role,                                    # What is our current IAM Role
                                    train_instance_count=1,                  # How many compute instances
                                    train_instance_type='ml.m4.xlarge',      # What kind of compute instances
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                    sagemaker_session=session)

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.

# Solution:
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        silent=0,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = None

# Solution:

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:rmse', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 6, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# ....................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning

xgb_attached = None

# Solution:

xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# 2019-12-07 17:12:13 Starting - Preparing the instances for training
# 2019-12-07 17:12:13 Downloading - Downloading input data
# 2019-12-07 17:12:13 Training - Training image download completed. Training in progress.
# 2019-12-07 17:12:13 Uploading - Uploading generated training model
# 2019-12-07 17:12:13 Completed - Training job completedArguments: train
# [2019-12-07:17:00:55:INFO] Running standalone xgboost training.
# [2019-12-07:17:00:55:INFO] Setting up HPO optimized metric to be : rmse
# [2019-12-07:17:00:55:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8507.13mb
# [2019-12-07:17:00:55:INFO] Determined delimiter of CSV input is ','
# [17:00:55] S3DistributionType set as FullyReplicated
# [17:00:57] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2019-12-07:17:00:57:INFO] Determined delimiter of CSV input is ','
# [17:00:57] S3DistributionType set as FullyReplicated
# [17:00:58] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [17:01:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 16 pruned nodes, max_depth=12
# [0]#011train-rmse:0.465945#011validation-rmse:0.470165
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [17:01:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 34 pruned nodes, max_depth=12
# [1]#011train-rmse:0.441566#011validation-rmse:0.450052
# [17:01:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 28 pruned nodes, max_depth=12
# [2]#011train-rmse:0.423109#011validation-rmse:0.435771
# [17:01:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 36 pruned nodes, max_depth=12
# [3]#011train-rmse:0.407385#011validation-rmse:0.425115
# [17:01:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 24 pruned nodes, max_depth=12
# [4]#011train-rmse:0.394549#011validation-rmse:0.416498
# [17:01:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 42 pruned nodes, max_depth=12
# [5]#011train-rmse:0.383408#011validation-rmse:0.409527
# [17:01:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 6 pruned nodes, max_depth=12
# [6]#011train-rmse:0.373728#011validation-rmse:0.403669
# [17:01:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 16 pruned nodes, max_depth=12
# [7]#011train-rmse:0.365201#011validation-rmse:0.398569
# [17:01:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 44 pruned nodes, max_depth=12
# [8]#011train-rmse:0.357032#011validation-rmse:0.394309
# [17:01:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 30 pruned nodes, max_depth=12
# [9]#011train-rmse:0.350639#011validation-rmse:0.389939
# [17:01:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 18 pruned nodes, max_depth=12
# [10]#011train-rmse:0.344431#011validation-rmse:0.386427
# [17:01:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 36 pruned nodes, max_depth=12
# [11]#011train-rmse:0.33686#011validation-rmse:0.382756
# [17:01:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 28 pruned nodes, max_depth=12
# [12]#011train-rmse:0.33224#011validation-rmse:0.379707
# [17:01:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 28 pruned nodes, max_depth=12
# [13]#011train-rmse:0.326728#011validation-rmse:0.376735
# [17:01:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 22 pruned nodes, max_depth=12
# [14]#011train-rmse:0.322586#011validation-rmse:0.374162
# [17:01:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 26 pruned nodes, max_depth=12
# [15]#011train-rmse:0.316668#011validation-rmse:0.370936
# [17:01:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 28 pruned nodes, max_depth=12
# [16]#011train-rmse:0.312564#011validation-rmse:0.368703
# [17:01:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 188 extra nodes, 24 pruned nodes, max_depth=12
# [17]#011train-rmse:0.308023#011validation-rmse:0.366679
# [17:01:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 32 pruned nodes, max_depth=12
# [18]#011train-rmse:0.30436#011validation-rmse:0.365011
# [17:01:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 28 pruned nodes, max_depth=12
# [19]#011train-rmse:0.300543#011validation-rmse:0.362886
# [17:01:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 28 pruned nodes, max_depth=12
# [20]#011train-rmse:0.297004#011validation-rmse:0.361064
# [17:02:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 20 pruned nodes, max_depth=12
# [21]#011train-rmse:0.294074#011validation-rmse:0.359513
# [17:02:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 34 pruned nodes, max_depth=12
# [22]#011train-rmse:0.29041#011validation-rmse:0.357866
# [17:02:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 36 pruned nodes, max_depth=12
# [23]#011train-rmse:0.286773#011validation-rmse:0.35607
# [17:02:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 32 pruned nodes, max_depth=12
# [24]#011train-rmse:0.284274#011validation-rmse:0.354824
# [17:02:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 24 pruned nodes, max_depth=12
# [25]#011train-rmse:0.281817#011validation-rmse:0.353447
# [17:02:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 20 pruned nodes, max_depth=12
# [26]#011train-rmse:0.279151#011validation-rmse:0.352114
# [17:02:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 22 pruned nodes, max_depth=12
# [27]#011train-rmse:0.276157#011validation-rmse:0.350536
# [17:02:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 30 pruned nodes, max_depth=12
# [28]#011train-rmse:0.273972#011validation-rmse:0.349452
# [17:02:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 24 pruned nodes, max_depth=12
# [29]#011train-rmse:0.271236#011validation-rmse:0.348483
# [17:02:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 24 pruned nodes, max_depth=12
# [30]#011train-rmse:0.268679#011validation-rmse:0.347431
# [17:02:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 36 pruned nodes, max_depth=12
# [31]#011train-rmse:0.266635#011validation-rmse:0.346245
# [17:02:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 26 pruned nodes, max_depth=12
# [32]#011train-rmse:0.264259#011validation-rmse:0.345127
# [17:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 20 pruned nodes, max_depth=12
# [33]#011train-rmse:0.262503#011validation-rmse:0.344383
# [17:02:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 28 pruned nodes, max_depth=12
# [34]#011train-rmse:0.259862#011validation-rmse:0.343728
# [17:02:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=12
# [35]#011train-rmse:0.258352#011validation-rmse:0.343163
# [17:02:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 34 pruned nodes, max_depth=12
# [36]#011train-rmse:0.256492#011validation-rmse:0.342467
# [17:02:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 26 pruned nodes, max_depth=12
# [37]#011train-rmse:0.253805#011validation-rmse:0.341524
# [17:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=12
# [38]#011train-rmse:0.252428#011validation-rmse:0.340788
# [17:02:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 32 pruned nodes, max_depth=12
# [39]#011train-rmse:0.250718#011validation-rmse:0.339886
# [17:02:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 28 pruned nodes, max_depth=12
# [40]#011train-rmse:0.249052#011validation-rmse:0.339364
# [17:02:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 28 pruned nodes, max_depth=12
# [41]#011train-rmse:0.247264#011validation-rmse:0.338247
# [17:03:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 28 pruned nodes, max_depth=12
# [42]#011train-rmse:0.245768#011validation-rmse:0.337674
# [17:03:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 26 pruned nodes, max_depth=12
# [43]#011train-rmse:0.243833#011validation-rmse:0.337063
# [17:03:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 12 pruned nodes, max_depth=12
# [44]#011train-rmse:0.242251#011validation-rmse:0.336829
# [17:03:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 32 pruned nodes, max_depth=12
# [45]#011train-rmse:0.240734#011validation-rmse:0.336095
# [17:03:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 26 pruned nodes, max_depth=12
# [46]#011train-rmse:0.239307#011validation-rmse:0.335628
# [17:03:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 20 pruned nodes, max_depth=12
# [47]#011train-rmse:0.237745#011validation-rmse:0.334936
# [17:03:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 22 pruned nodes, max_depth=12
# [48]#011train-rmse:0.236606#011validation-rmse:0.334182
# [17:03:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 14 pruned nodes, max_depth=12
# [49]#011train-rmse:0.235365#011validation-rmse:0.333565
# [17:03:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 16 pruned nodes, max_depth=12
# [50]#011train-rmse:0.234506#011validation-rmse:0.333157
# [17:03:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 32 pruned nodes, max_depth=12
# [51]#011train-rmse:0.232979#011validation-rmse:0.332814
# [17:03:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 26 pruned nodes, max_depth=12
# [52]#011train-rmse:0.231033#011validation-rmse:0.332396
# [17:03:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 28 pruned nodes, max_depth=12
# [53]#011train-rmse:0.229792#011validation-rmse:0.331613
# [17:03:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 18 pruned nodes, max_depth=12
# [54]#011train-rmse:0.229006#011validation-rmse:0.33095
# [17:03:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 24 pruned nodes, max_depth=12
# [55]#011train-rmse:0.227876#011validation-rmse:0.33059
# [17:03:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 16 pruned nodes, max_depth=12
# [56]#011train-rmse:0.226951#011validation-rmse:0.330222
# [17:03:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 16 pruned nodes, max_depth=12
# [57]#011train-rmse:0.225888#011validation-rmse:0.329985
# [17:03:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 16 pruned nodes, max_depth=12
# [58]#011train-rmse:0.22501#011validation-rmse:0.329542
# [17:03:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 26 pruned nodes, max_depth=12
# [59]#011train-rmse:0.224133#011validation-rmse:0.329299
# [17:03:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 26 pruned nodes, max_depth=12
# [60]#011train-rmse:0.223133#011validation-rmse:0.329133
# [17:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 30 pruned nodes, max_depth=12
# [61]#011train-rmse:0.222155#011validation-rmse:0.328563
# [17:03:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 20 pruned nodes, max_depth=12
# [62]#011train-rmse:0.220274#011validation-rmse:0.32812
# [17:03:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 20 pruned nodes, max_depth=12
# [63]#011train-rmse:0.218887#011validation-rmse:0.327767
# [17:04:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 28 pruned nodes, max_depth=12
# [64]#011train-rmse:0.217856#011validation-rmse:0.327503
# [17:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 12 pruned nodes, max_depth=12
# [65]#011train-rmse:0.216835#011validation-rmse:0.326973
# [17:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=12
# [66]#011train-rmse:0.216127#011validation-rmse:0.326501
# [17:04:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 22 pruned nodes, max_depth=12
# [67]#011train-rmse:0.215146#011validation-rmse:0.326165
# [17:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 18 pruned nodes, max_depth=12
# [68]#011train-rmse:0.213983#011validation-rmse:0.325568
# [17:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 22 pruned nodes, max_depth=12
# [69]#011train-rmse:0.212832#011validation-rmse:0.325355
# [17:04:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 38 pruned nodes, max_depth=12
# [70]#011train-rmse:0.211538#011validation-rmse:0.324829
# [17:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=12
# [71]#011train-rmse:0.210579#011validation-rmse:0.324355
# [17:04:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 30 pruned nodes, max_depth=12
# [72]#011train-rmse:0.209517#011validation-rmse:0.323987
# [17:04:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 14 pruned nodes, max_depth=12
# [73]#011train-rmse:0.20866#011validation-rmse:0.323637
# [17:04:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 22 pruned nodes, max_depth=12
# [74]#011train-rmse:0.207578#011validation-rmse:0.323346
# [17:04:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 36 pruned nodes, max_depth=12
# [75]#011train-rmse:0.206462#011validation-rmse:0.322977
# [17:04:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=12
# [76]#011train-rmse:0.205951#011validation-rmse:0.322646
# [17:04:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=12
# [77]#011train-rmse:0.20532#011validation-rmse:0.322407
# [17:04:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=12
# [78]#011train-rmse:0.204611#011validation-rmse:0.322118
# [17:04:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 10 pruned nodes, max_depth=12
# [79]#011train-rmse:0.203713#011validation-rmse:0.321864
# [17:04:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 8 pruned nodes, max_depth=12
# [80]#011train-rmse:0.203158#011validation-rmse:0.321588
# [17:04:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 32 pruned nodes, max_depth=12
# [81]#011train-rmse:0.202348#011validation-rmse:0.321467
# [17:04:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 24 pruned nodes, max_depth=12
# [82]#011train-rmse:0.20136#011validation-rmse:0.321169
# [17:04:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 18 pruned nodes, max_depth=12
# [83]#011train-rmse:0.200658#011validation-rmse:0.32086
# [17:04:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 28 pruned nodes, max_depth=12
# [84]#011train-rmse:0.199637#011validation-rmse:0.320603
# [17:04:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 38 pruned nodes, max_depth=12
# [85]#011train-rmse:0.198502#011validation-rmse:0.320505
# [17:05:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 10 pruned nodes, max_depth=12
# [86]#011train-rmse:0.197924#011validation-rmse:0.32015
# [17:05:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 28 pruned nodes, max_depth=12
# [87]#011train-rmse:0.196991#011validation-rmse:0.319885
# [17:05:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 16 pruned nodes, max_depth=12
# [88]#011train-rmse:0.195642#011validation-rmse:0.319855
# [17:05:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=12
# [89]#011train-rmse:0.194988#011validation-rmse:0.31945
# [17:05:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 26 pruned nodes, max_depth=12
# [90]#011train-rmse:0.194314#011validation-rmse:0.319379
# [17:05:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 16 pruned nodes, max_depth=12
# [91]#011train-rmse:0.193553#011validation-rmse:0.319163
# [17:05:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 24 pruned nodes, max_depth=12
# [92]#011train-rmse:0.193164#011validation-rmse:0.318829
# [17:05:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 26 pruned nodes, max_depth=12
# [93]#011train-rmse:0.192014#011validation-rmse:0.318717
# [17:05:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=12
# [94]#011train-rmse:0.19156#011validation-rmse:0.31855
# [17:05:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 22 pruned nodes, max_depth=12
# [95]#011train-rmse:0.190557#011validation-rmse:0.318322
# [17:05:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 20 pruned nodes, max_depth=12
# [96]#011train-rmse:0.189546#011validation-rmse:0.318155
# [17:05:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=12
# [97]#011train-rmse:0.189158#011validation-rmse:0.318046
# [17:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 24 pruned nodes, max_depth=12
# [98]#011train-rmse:0.188655#011validation-rmse:0.317792
# [17:05:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=12
# [99]#011train-rmse:0.187965#011validation-rmse:0.317531
# [17:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 34 pruned nodes, max_depth=12
# [100]#011train-rmse:0.1871#011validation-rmse:0.317344
# [17:05:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 42 pruned nodes, max_depth=12
# [101]#011train-rmse:0.186152#011validation-rmse:0.317278
# [17:05:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 32 pruned nodes, max_depth=12
# [102]#011train-rmse:0.1853#011validation-rmse:0.316968
# [17:05:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 22 pruned nodes, max_depth=12
# [103]#011train-rmse:0.184143#011validation-rmse:0.316833
# [17:05:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 12 pruned nodes, max_depth=12
# [104]#011train-rmse:0.183541#011validation-rmse:0.316721
# [17:05:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 34 pruned nodes, max_depth=12
# [105]#011train-rmse:0.182346#011validation-rmse:0.316661
# [17:05:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=12
# [106]#011train-rmse:0.181858#011validation-rmse:0.316472
# [17:06:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 28 pruned nodes, max_depth=12
# [107]#011train-rmse:0.180883#011validation-rmse:0.316265
# [17:06:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=12
# [108]#011train-rmse:0.180465#011validation-rmse:0.316102
# [17:06:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 14 pruned nodes, max_depth=12
# [109]#011train-rmse:0.179828#011validation-rmse:0.315818
# [17:06:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 32 pruned nodes, max_depth=12
# [110]#011train-rmse:0.179223#011validation-rmse:0.315741
# [17:06:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 32 pruned nodes, max_depth=12
# [111]#011train-rmse:0.178498#011validation-rmse:0.315684
# [17:06:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=12
# [112]#011train-rmse:0.178194#011validation-rmse:0.315728
# [17:06:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 28 pruned nodes, max_depth=12
# [113]#011train-rmse:0.177547#011validation-rmse:0.315412
# [17:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=12
# [114]#011train-rmse:0.177054#011validation-rmse:0.315489
# [17:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 36 pruned nodes, max_depth=12
# [115]#011train-rmse:0.17624#011validation-rmse:0.31514
# [17:06:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 34 pruned nodes, max_depth=12
# [116]#011train-rmse:0.175472#011validation-rmse:0.315151
# [17:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=12
# [117]#011train-rmse:0.17517#011validation-rmse:0.315031
# [17:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 28 pruned nodes, max_depth=12
# [118]#011train-rmse:0.174388#011validation-rmse:0.314735
# [17:06:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 24 pruned nodes, max_depth=12
# [119]#011train-rmse:0.173955#011validation-rmse:0.31459
# [17:06:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 28 pruned nodes, max_depth=12
# [120]#011train-rmse:0.173337#011validation-rmse:0.314509
# [17:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=12
# [121]#011train-rmse:0.172832#011validation-rmse:0.314485
# [17:06:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 16 pruned nodes, max_depth=12
# [122]#011train-rmse:0.172206#011validation-rmse:0.314476
# [17:06:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 30 pruned nodes, max_depth=12
# [123]#011train-rmse:0.171238#011validation-rmse:0.314513
# [17:06:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 30 pruned nodes, max_depth=12
# [124]#011train-rmse:0.170318#011validation-rmse:0.314403
# [17:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=12
# [125]#011train-rmse:0.169665#011validation-rmse:0.314177
# [17:06:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 18 pruned nodes, max_depth=12
# [126]#011train-rmse:0.169054#011validation-rmse:0.313897
# [17:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 22 pruned nodes, max_depth=12
# [127]#011train-rmse:0.168547#011validation-rmse:0.313786
# [17:06:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 12 pruned nodes, max_depth=12
# [128]#011train-rmse:0.168066#011validation-rmse:0.313896
# [17:07:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 24 pruned nodes, max_depth=12
# [129]#011train-rmse:0.167598#011validation-rmse:0.313752
# [17:07:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 14 pruned nodes, max_depth=12
# [130]#011train-rmse:0.1673#011validation-rmse:0.313642
# [17:07:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 24 pruned nodes, max_depth=12
# [131]#011train-rmse:0.166932#011validation-rmse:0.313567
# [17:07:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 38 pruned nodes, max_depth=12
# [132]#011train-rmse:0.166012#011validation-rmse:0.313416
# [17:07:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 28 pruned nodes, max_depth=12
# [133]#011train-rmse:0.165425#011validation-rmse:0.313436
# [17:07:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 32 pruned nodes, max_depth=12
# [134]#011train-rmse:0.164826#011validation-rmse:0.313361
# [17:07:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 42 pruned nodes, max_depth=12
# [135]#011train-rmse:0.164329#011validation-rmse:0.313301
# [17:07:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 24 pruned nodes, max_depth=12
# [136]#011train-rmse:0.163514#011validation-rmse:0.313236
# [17:07:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 50 pruned nodes, max_depth=12
# [137]#011train-rmse:0.162427#011validation-rmse:0.313132
# [17:07:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 16 pruned nodes, max_depth=12
# [138]#011train-rmse:0.162005#011validation-rmse:0.312984
# [17:07:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 16 pruned nodes, max_depth=12
# [139]#011train-rmse:0.161657#011validation-rmse:0.312912
# [17:07:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 30 pruned nodes, max_depth=12
# [140]#011train-rmse:0.161098#011validation-rmse:0.312719
# [17:07:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 44 pruned nodes, max_depth=12
# [141]#011train-rmse:0.160739#011validation-rmse:0.312684
# [17:07:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=12
# [142]#011train-rmse:0.160398#011validation-rmse:0.312622
# [17:07:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 30 pruned nodes, max_depth=12
# [143]#011train-rmse:0.159363#011validation-rmse:0.312618
# [17:07:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 28 pruned nodes, max_depth=12
# [144]#011train-rmse:0.158543#011validation-rmse:0.312677
# [17:07:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 18 pruned nodes, max_depth=12
# [145]#011train-rmse:0.158319#011validation-rmse:0.312484
# [17:07:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 34 pruned nodes, max_depth=12
# [146]#011train-rmse:0.157962#011validation-rmse:0.312547
# [17:07:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 14 pruned nodes, max_depth=12
# [147]#011train-rmse:0.157645#011validation-rmse:0.312483
# [17:07:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 28 pruned nodes, max_depth=12
# [148]#011train-rmse:0.156641#011validation-rmse:0.312335
# [17:07:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 40 pruned nodes, max_depth=12
# [149]#011train-rmse:0.156233#011validation-rmse:0.312255
# [17:08:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=12
# [150]#011train-rmse:0.155782#011validation-rmse:0.312227
# [17:08:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 26 pruned nodes, max_depth=12
# [151]#011train-rmse:0.155164#011validation-rmse:0.312361
# [17:08:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 30 pruned nodes, max_depth=12
# [152]#011train-rmse:0.15476#011validation-rmse:0.312241
# [17:08:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 42 pruned nodes, max_depth=12
# [153]#011train-rmse:0.154319#011validation-rmse:0.312304
# [17:08:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=12
# [154]#011train-rmse:0.153892#011validation-rmse:0.312154
# [17:08:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=12
# [155]#011train-rmse:0.153609#011validation-rmse:0.311969
# [17:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=12
# [156]#011train-rmse:0.153245#011validation-rmse:0.311925
# [17:08:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=12
# [157]#011train-rmse:0.152788#011validation-rmse:0.311887
# [17:08:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=12
# [158]#011train-rmse:0.152564#011validation-rmse:0.311759
# [17:08:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=12
# [159]#011train-rmse:0.152294#011validation-rmse:0.311693
# [17:08:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 22 pruned nodes, max_depth=12
# [160]#011train-rmse:0.152068#011validation-rmse:0.311564
# [17:08:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 18 pruned nodes, max_depth=12
# [161]#011train-rmse:0.151586#011validation-rmse:0.31147
# [17:08:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 32 pruned nodes, max_depth=12
# [162]#011train-rmse:0.150738#011validation-rmse:0.311351
# [17:08:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 38 pruned nodes, max_depth=12
# [163]#011train-rmse:0.150254#011validation-rmse:0.311181
# [17:08:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=12
# [164]#011train-rmse:0.150053#011validation-rmse:0.310999
# [17:08:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 38 pruned nodes, max_depth=12
# [165]#011train-rmse:0.149799#011validation-rmse:0.310812
# [17:08:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 18 pruned nodes, max_depth=12
# [166]#011train-rmse:0.149458#011validation-rmse:0.310831
# [17:08:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 18 pruned nodes, max_depth=12
# [167]#011train-rmse:0.149248#011validation-rmse:0.310615
# [17:08:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 24 pruned nodes, max_depth=12
# [168]#011train-rmse:0.148702#011validation-rmse:0.310582
# [17:08:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=12
# [169]#011train-rmse:0.148529#011validation-rmse:0.310451
# [17:08:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=12
# [170]#011train-rmse:0.148298#011validation-rmse:0.310371
# [17:09:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=12
# [171]#011train-rmse:0.148071#011validation-rmse:0.310303
# [17:09:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=12
# [172]#011train-rmse:0.147552#011validation-rmse:0.310084
# [17:09:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 20 pruned nodes, max_depth=12
# [173]#011train-rmse:0.147274#011validation-rmse:0.309895
# [17:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 24 pruned nodes, max_depth=12
# [174]#011train-rmse:0.146631#011validation-rmse:0.309619
# [17:09:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 34 pruned nodes, max_depth=12
# [175]#011train-rmse:0.14618#011validation-rmse:0.309367
# [17:09:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 22 pruned nodes, max_depth=12
# [176]#011train-rmse:0.145703#011validation-rmse:0.309352
# [17:09:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 36 pruned nodes, max_depth=12
# [177]#011train-rmse:0.14539#011validation-rmse:0.309315
# [17:09:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 30 pruned nodes, max_depth=12
# [178]#011train-rmse:0.145176#011validation-rmse:0.309188
# [17:09:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 16 pruned nodes, max_depth=12
# [179]#011train-rmse:0.144832#011validation-rmse:0.309138
# [17:09:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 20 pruned nodes, max_depth=12
# [180]#011train-rmse:0.144512#011validation-rmse:0.309197
# [17:09:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 16 pruned nodes, max_depth=12
# [181]#011train-rmse:0.144279#011validation-rmse:0.308966
# [17:09:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 22 pruned nodes, max_depth=12
# [182]#011train-rmse:0.143978#011validation-rmse:0.309
# [17:09:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 20 pruned nodes, max_depth=12
# [183]#011train-rmse:0.143728#011validation-rmse:0.308993
# [17:09:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 12 pruned nodes, max_depth=12
# [184]#011train-rmse:0.14358#011validation-rmse:0.308937
# [17:09:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 30 pruned nodes, max_depth=12
# [185]#011train-rmse:0.14293#011validation-rmse:0.308882
# [17:09:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 34 pruned nodes, max_depth=12
# [186]#011train-rmse:0.142435#011validation-rmse:0.308757
# [17:09:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 34 pruned nodes, max_depth=12
# [187]#011train-rmse:0.141968#011validation-rmse:0.308755
# [17:09:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 18 pruned nodes, max_depth=12
# [188]#011train-rmse:0.141541#011validation-rmse:0.308576
# [17:09:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=12
# [189]#011train-rmse:0.141417#011validation-rmse:0.308649
# [17:09:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 42 pruned nodes, max_depth=12
# [190]#011train-rmse:0.141193#011validation-rmse:0.308615
# [17:09:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 32 pruned nodes, max_depth=12
# [191]#011train-rmse:0.140537#011validation-rmse:0.308613
# [17:09:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 34 pruned nodes, max_depth=12
# [192]#011train-rmse:0.140213#011validation-rmse:0.308525
# [17:10:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 20 pruned nodes, max_depth=12
# [193]#011train-rmse:0.139805#011validation-rmse:0.308291
# [17:10:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 8 pruned nodes, max_depth=12
# [194]#011train-rmse:0.139531#011validation-rmse:0.308193
# [17:10:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=12
# [195]#011train-rmse:0.139395#011validation-rmse:0.308189
# [17:10:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 14 pruned nodes, max_depth=12
# [196]#011train-rmse:0.13906#011validation-rmse:0.308294
# [17:10:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 40 pruned nodes, max_depth=12
# [197]#011train-rmse:0.138609#011validation-rmse:0.308373
# [17:10:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 34 pruned nodes, max_depth=12
# [198]#011train-rmse:0.138067#011validation-rmse:0.308404
# [17:10:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=12
# [199]#011train-rmse:0.137668#011validation-rmse:0.307957
# [17:10:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=12
# [200]#011train-rmse:0.13752#011validation-rmse:0.307858
# [17:10:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 28 pruned nodes, max_depth=12
# [201]#011train-rmse:0.136974#011validation-rmse:0.30769
# [17:10:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=12
# [202]#011train-rmse:0.136779#011validation-rmse:0.307711
# [17:10:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 20 pruned nodes, max_depth=12
# [203]#011train-rmse:0.136339#011validation-rmse:0.307686
# [17:10:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=12
# [204]#011train-rmse:0.136032#011validation-rmse:0.307694
# [17:10:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 24 pruned nodes, max_depth=12
# [205]#011train-rmse:0.135344#011validation-rmse:0.307723
# [17:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 14 pruned nodes, max_depth=12
# [206]#011train-rmse:0.134938#011validation-rmse:0.307641
# [17:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 46 pruned nodes, max_depth=12
# [207]#011train-rmse:0.13457#011validation-rmse:0.307729
# [17:10:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 32 pruned nodes, max_depth=12
# [208]#011train-rmse:0.133963#011validation-rmse:0.307759
# [17:10:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 18 pruned nodes, max_depth=12
# [209]#011train-rmse:0.133642#011validation-rmse:0.307677
# [17:10:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 22 pruned nodes, max_depth=12
# [210]#011train-rmse:0.133337#011validation-rmse:0.307633
# [17:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 38 pruned nodes, max_depth=12
# [211]#011train-rmse:0.132945#011validation-rmse:0.307639
# [17:10:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 26 pruned nodes, max_depth=12
# [212]#011train-rmse:0.1327#011validation-rmse:0.307599
# [17:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 22 pruned nodes, max_depth=12
# [213]#011train-rmse:0.13232#011validation-rmse:0.307487
# [17:11:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 16 pruned nodes, max_depth=12
# [214]#011train-rmse:0.131957#011validation-rmse:0.3075
# [17:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 34 pruned nodes, max_depth=12
# [215]#011train-rmse:0.131248#011validation-rmse:0.307455
# [17:11:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=12
# [216]#011train-rmse:0.131079#011validation-rmse:0.307511
# [17:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 16 pruned nodes, max_depth=12
# [217]#011train-rmse:0.130829#011validation-rmse:0.307583
# [17:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 20 pruned nodes, max_depth=11
# [218]#011train-rmse:0.130496#011validation-rmse:0.307562
# [17:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 42 pruned nodes, max_depth=12
# [219]#011train-rmse:0.130177#011validation-rmse:0.307526
# [17:11:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=11
# [220]#011train-rmse:0.130104#011validation-rmse:0.307588
# [17:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=9
# [221]#011train-rmse:0.129978#011validation-rmse:0.307539
# [17:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=12
# [222]#011train-rmse:0.129831#011validation-rmse:0.307564
# [17:11:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 22 pruned nodes, max_depth=6
# [223]#011train-rmse:0.129789#011validation-rmse:0.307498
# [17:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 18 pruned nodes, max_depth=12
# [224]#011train-rmse:0.129537#011validation-rmse:0.307488
# [17:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 26 pruned nodes, max_depth=12
# [225]#011train-rmse:0.129391#011validation-rmse:0.307364
# [17:11:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 36 pruned nodes, max_depth=8
# [226]#011train-rmse:0.129276#011validation-rmse:0.307315
# [17:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 46 pruned nodes, max_depth=12
# [227]#011train-rmse:0.128729#011validation-rmse:0.307621
# [17:11:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 28 pruned nodes, max_depth=12
# [228]#011train-rmse:0.128449#011validation-rmse:0.307561
# [17:11:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 38 pruned nodes, max_depth=12
# [229]#011train-rmse:0.128181#011validation-rmse:0.307537
# [17:11:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 32 pruned nodes, max_depth=12
# [230]#011train-rmse:0.12771#011validation-rmse:0.307527
# [17:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 36 pruned nodes, max_depth=12
# [231]#011train-rmse:0.127487#011validation-rmse:0.307451
# [17:11:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 30 pruned nodes, max_depth=12
# [232]#011train-rmse:0.127338#011validation-rmse:0.30748
# [17:11:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 40 pruned nodes, max_depth=3
# [233]#011train-rmse:0.127315#011validation-rmse:0.307512
# [17:11:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=12
# [234]#011train-rmse:0.127128#011validation-rmse:0.307459
# [17:12:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 34 pruned nodes, max_depth=12
# [235]#011train-rmse:0.126902#011validation-rmse:0.307374
# [17:12:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 26 pruned nodes, max_depth=7
# [236]#011train-rmse:0.126779#011validation-rmse:0.307453
# Stopping. Best iteration:
# [226]#011train-rmse:0.129276#011validation-rmse:0.307315
#
# Training seconds: 712
# Billable seconds: 712

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = None

# Solution:
xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ....................Arguments: serve
# [2019-12-07 17:19:46 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2019-12-07 17:19:46 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2019-12-07 17:19:46 +0000] [1] [INFO] Using worker: gevent
# [2019-12-07 17:19:46 +0000] [37] [INFO] Booting worker with pid: 37
# [2019-12-07 17:19:46 +0000] [38] [INFO] Booting worker with pid: 38
# [2019-12-07 17:19:46 +0000] [39] [INFO] Booting worker with pid: 39
# [2019-12-07 17:19:46 +0000] [40] [INFO] Booting worker with pid: 40
# [2019-12-07:17:19:46:INFO] Model loaded successfully for worker : 37
# [2019-12-07:17:19:46:INFO] Model loaded successfully for worker : 40
# [2019-12-07:17:19:46:INFO] Model loaded successfully for worker : 38
# [2019-12-07:17:19:46:INFO] Model loaded successfully for worker : 39
# [2019-12-07:17:20:15:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:15:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:15:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:15:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:15:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:15:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:15:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:15:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:16:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:16:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:16:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:16:INFO] Determined delimiter of CSV input is ','
# 2019-12-07T17:20:13.067:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:17:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:17:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:19:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:19:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:21:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:21:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:21:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:22:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:24:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:24:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:26:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:26:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:26:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:27:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:27:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:27:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:27:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:29:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:29:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:31:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:31:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:32:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:32:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:32:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:32:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:33:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:33:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:33:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:33:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:33:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:34:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:34:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:34:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:34:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:34:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:34:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:34:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:34:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:36:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:36:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:36:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:36:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:36:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:36:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:36:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:36:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:38:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:38:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:38:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:38:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:38:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:38:INFO] Determined delimiter of CSV input is ','
# [2019-12-07:17:20:38:INFO] Sniff delimiter as ','
# [2019-12-07:17:20:38:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-1-037802178319/xgboost-191207-1650-004-1c7afe1b-2019-12-07-17-16-36-638/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86852

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
